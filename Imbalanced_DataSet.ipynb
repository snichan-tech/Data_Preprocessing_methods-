# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
dataset=pd.read_csv("D:\Pandas\Social_Network_Ads.csv")

# %%
dataset.head(5)
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
dataset["Purchased"].value_counts() # 0 is more and 1 is less
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
x=dataset.iloc[:,:-1]
y=dataset["Purchased"]

# %%
#from sklearn.linear_model import LinearRegression

# %%
#lr=LinearRegression()

# %%
#lr.fit(x_train,y_train)

# %%
#lr.score(x_test,y_test)*100

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
ru=RandomUnderSampler()

# %%
ru_x,ru_y=ru.fit_resample(x,y)

# %%
ru_y.value_counts() # now the dataset is balanced
# Out:
# Purchased
# 0    143
# 1    143
# Name: count, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 88.75

# %%
from imblearn.under_sampling import RandomUnderSampler # ex. 400 cats and 100 dogs then just choose 100 random cats and now u got 100 cats and 100 dogs 
from imblearn.over_sampling import RandomOverSampler # ex. 400 cats and 100 dogs then just increase the count of dogs to 400 and now you got 400 dogs and 400 cats

# %%
ro= RandomOverSampler()
ro_x,ro_y=ro.fit_resample(x,y)

# %%
ro_y.value_counts()
# Out:
# Purchased
# 0    257
# 1    257
# Name: count, dtype: int64

# %%
x_train1,x_test1,y_train1,y_test1=train_test_split(ro_x,ro_y,test_size=0.2,random_state=42)

# %%
lr1=LogisticRegression()

# %%
lr1.fit(x_train1,y_train1)
# Out:
# LogisticRegression()

# %%
lr1.score(ro_x,ro_y)*100
# Out:
# 83.26848249027238

# %%
ru=RandomUnderSampler()

# %%
ru_x,ru_y=ru.fit_resample(x,y)

# %%
ru_y.value_counts()
# Out:
# Purchased
# 0    143
# 1    143
# Name: count, dtype: int64

# %%
lr1.score(ru_x,ru_y)*100
# Out:
# 83.21678321678321
