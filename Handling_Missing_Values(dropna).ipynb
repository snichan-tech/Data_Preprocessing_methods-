# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
dataset=pd.read_csv(r"D:\Pandas\loan_data_set.csv")

# %%
dataset
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
dataset.shape
# Out:
# (614, 13)

# %%
dataset.isnull()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 609    False   False    False       False      False          False
# 610    False   False    False       False      False          False
# 611    False   False    False       False      False          False
# 612    False   False    False       False      False          False
# 613    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False        True             False
# ...

# %%
dataset.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       6
# CoapplicantIncome     2
# LoanAmount           23
# Loan_Amount_Term     15
# Credit_History       50
# Property_Area         2
# Loan_Status           0
# dtype: int64

# %%
sns.heatmap(dataset.isnull())
plt.show()#1 is almost white which means not null

# %%
sns.heatmap(dataset.notnull())
plt.show()# 0 is black which means null

# %%
dataset.dropna(inplace=True)

# %%
dataset.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
# now we don't have any null values

# %%
#if the data is categorical (string)
#Handling missing values (Imputing categorical values )
#Method 1: fill with a const(not recommended )
#Method 2 : fill with mode () value 
#Method 3: bbfill and fffill axis=1 (columwise )

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 469 entries, 1 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            469 non-null    object
#  1   Gender             469 non-null    object
#  2   Married            469 non-null    object
#  3   Dependents         469 non-null    object
#  4   Education          469 non-null    object
#  5   Self_Employed      469 non-null    object
#  6   ApplicantIncome    469 non-null    float64
#  7   CoapplicantIncome  469 non-null    float64
#  8   LoanAmount         469 non-null    float64
#  9   Loan_Amount_Term   469 non-null    float64
#  10  Credit_History     469 non-null    float64
#  11  Property_Area      469 non-null    object
#  12  Loan_Status        469 non-null    object
# dtypes: float64(5), object(8)
# memory usage: 51.3+ KB
