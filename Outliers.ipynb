# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset=pd.read_csv(r"D:\Pandas\loan_data_set.csv")

# %%
dataset
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
sns.boxplot(dataset["ApplicantIncome"])
plt.show()

# %%
sns.boxplot(dataset["CoapplicantIncome"])
plt.show()

# %%
sns.displot(dataset["CoapplicantIncome"])
plt.show()

# %%
sns.displot(dataset["ApplicantIncome"])
plt.show()

# %%
q1 = dataset["CoapplicantIncome"].quantile(0.25)
q3 = dataset["ApplicantIncome"].quantile(0.75)

# %%
IQR=q3-q1

# %%
min_range=q1-(1.5*IQR)
max_range=q3+(1.5*IQR)

# %%
new_dataset=dataset[dataset["CoapplicantIncome"] <= max_range]

# %%
new_dataset
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
sns.displot(new_dataset["CoapplicantIncome"])
plt.show()

# %%
sns.boxplot(new_dataset["CoapplicantIncome"])
plt.show()

# %%
new_dataset_1=dataset[dataset["ApplicantIncome"] <= max_range]

# %%
sns.boxplot(new_dataset_1["ApplicantIncome"])
plt.show()
